# %%
# when working with team always use title , xlable and ylable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2D Line Plot
# 1.Bivariate Analysis
# 2. -> numerical and numerical -> numerical
# 3.Use case - Time series data

# %%
# plotting a simple function
price = [10000,20000,30000,40000,50000]
year = [2015,2016,2017,2018,2019]

# %%
plt.plot(year , price)

# %%
# # from a pandas dataframe
df = pd.read_csv(r'D:\Study\Data Science\Level 1\Frameworks\Matplotlib\Datasets\04_sharma-kohli.csv')
df.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
# plotting multiple plots
plt.plot(df['index'] , df['RG Sharma'])
plt.plot(df['index'] , df['V Kohli'])

# %%
# lable and title
plt.plot(df['index'] , df['RG Sharma'])
plt.plot(df['index'] , df['V Kohli'])
plt.title('Rohit Sharma Vs Virat Kohli')
plt.xlabel('Year')
plt.ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
# color(hex) and line(width and style) and marker(size)
plt.plot(df['index'] , df['RG Sharma'] , color = 'green')
plt.plot(df['index'] , df['V Kohli'] , color = 'red')

# %%
# using hex
plt.plot(df['index'] , df['RG Sharma'] , color = '#58B0A7')
plt.plot(df['index'] , df['V Kohli'] , color = '#9058B0')

# %%
# line (style)
plt.plot(df['index'] , df['RG Sharma'] , color = '#58B0A7' , linestyle = 'dashed')
plt.plot(df['index'] , df['V Kohli'] , color = '#9058B0' , linestyle = 'dashdot')

# %%
# line(linewidth)
plt.plot(df['index'] , df['RG Sharma'] , color = '#58B0A7' , linestyle = 'dashed',linewidth = 5)
plt.plot(df['index'] , df['V Kohli'] , color = '#9058B0' , linestyle = 'dashdot' , linewidth = 5)

# %%
# marker (size and varaitions)
plt.plot(df['index'] , df['RG Sharma'] , color = 'green',marker = '>' , markersize = 10)
plt.plot(df['index'] , df['V Kohli'] , color = 'red')

# %%
# legend and location
plt.plot(df['index'] , df['RG Sharma'] , color = 'green' , label = 'Rohit')
plt.plot(df['index'] , df['V Kohli'] , color = 'red' , label = 'Virat')
plt.legend(loc = 'best')

# %%
# limiting axes

# %%
# somtime your datset may have some outlier which can leads to the distortion of the graph to avoid this we use limit axes parameter
plt.plot(df['index'] , df['RG Sharma'] , color = 'green' , label = 'Rohit')
plt.plot(df['index'] , df['V Kohli'] , color = 'red' , label = 'Virat')
plt.legend(loc = 'best')
plt.ylim(0,1000)
plt.xlim(2008,2017)
# Out:
# (2008.0, 2017.0)

# %%
# grid
plt.plot(df['index'] , df['RG Sharma'] , color = 'green' , label = 'Rohit')
plt.plot(df['index'] , df['V Kohli'] , color = 'red' , label = 'Virat')
plt.legend(loc = 'best')
plt.ylim(0,1000)
plt.xlim(2008,2017)
plt.grid()

# %%
# show
plt.plot(df['index'] , df['RG Sharma'] , color = 'green' , label = 'Rohit')
plt.plot(df['index'] , df['V Kohli'] , color = 'red' , label = 'Virat')
plt.legend(loc = 'best')
plt.ylim(0,1000)
plt.xlim(2008,2017)
plt.show()

# %% [markdown]
# ## scatter plot()
# 1.Bivariate Analysis
# 2.numerical vs numerical
# 3.Use case - Finding correlation
# 4.2d plot is a special case of a scatter plot

# %%
# plt.scatter simple function
x = np.linspace(-10,10,50)
y = 10 * x + 3 + np.random.randint(0,300,50)

# %%
plt.scatter(x , y)
plt.show()

# %%
# plt.scatter on dataframe
df = pd.read_csv(r'Datasets\02_batter.csv')
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
plt.scatter(df['strike_rate'] , df['avg'] , color = 'red' , marker='+'  )
# here we have s in place of marker size , but behahaves little different that marker size

# %%
# size s parameter
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(tips['total_bill'], tips['tip'] , s = tips['size']*20 , marker='+' , color = 'green')

# %%
# scatter plot using plot function
plt.plot(tips['total_bill'], tips['tip'] , '>')

# %%
# plot() vs scatter plot()
# on large dataset => use plot() => it is faster
# on small dataset use scatter plot() => it is slower

# %% [markdown]
# ## Bar Chart()
#
# 1.Bivariate Analysis
# 2.Numerical vs Categorical
# 3.Use case - Aggregate analysis of groups

# %%
# simple bar chart
color = ['red' , 'green' , 'blue' , 'yellow' , 'pink']
children = [10,20,40,61,30]

# %%
plt.bar(color , children)
# Out:
# <BarContainer object of 5 artists>

# %%
# barh => horizontal bar chart
# no need of lablel(legend) in simple bar chart but used in myltiple and stacjed bar chart
plt.barh(color , children , color = 'pink' , )
plt.show()

# %%
# multiple bar chart
df = pd.read_csv(r'Datasets\01_batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
# unlike plot() here colors overlap on each other to avoid this we can plot mupliple bar chart .
# But matplotlib does have any direct function to implement the multiple bar chart 

# the problem
plt.bar(df['batsman'] , df['2016'])
plt.bar(df['batsman'] , df['2017'] , color = 'red')
# Out:
# <BarContainer object of 5 artists>

# %%
# the solution
plt.title("Seasonwise batsman Runs")
plt.bar(np.arange(df.shape[0]) - 0.2 , df['2015'] , width = 0.2  , color = 'yellow' , label = '2015')
plt.bar(np.arange(df.shape[0])  , df['2016'] , width = 0.2  , color = 'blue' , label = '2016')
plt.bar(np.arange(df.shape[0]) + 0.2 , df['2017'] , width = 0.2  , color = 'red' , label = '2017')
plt.legend()
plt.xticks(np.arange(df.shape[0]) , df['batsman'])
plt.show()

# %%
np.arange(df.shape[0])
# Out:
# array([0, 1, 2, 3, 4])

# %%
df.shape
# Out:
# (5, 4)

# %%
# xticks
# one use we seen in above and one use is below

# %%
# a problem
color = ['redredredred ' , 'greengreengreengreen' , 'bluevblueblueblue' , 'yellowyellowyellowyellow' , 'pinkpinkpinkpink']
children = [10,20,40,61,30]

plt.bar(color , children)
# plt.xticks(rotation = 'vertical')
plt.show()

# %%
# solution
color = ['redredredred ' , 'greengreengreengreen' , 'bluevblueblueblue' , 'yellowyellowyellowyellow' , 'pinkpinkpinkpink']
children = [10,20,40,61,30]

plt.bar(color , children)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
# stacked bar chart => use the bottom parametr wisely
plt.bar(df['batsman'],df['2017'],label='2017')
plt.bar(df['batsman'],df['2016'],bottom=df['2017'],label='2016')
plt.bar(df['batsman'],df['2015'],bottom=(df['2016'] + df['2017']),label='2015')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Histogram
# 1.Univariate Analysis
# 2.col
# 3.Use case - Frequency Count

# %%
# simple data
data = [21,43,23,74,39,16]
plt.hist(data , bins = [10,20,30,40,50,60,70,80])
plt.show()

# %%
# using data
df = pd.read_csv(r'D:\Study\Data Science\Level 1\Frameworks\Matplotlib\Datasets\06_vk.csv')
df.head()
# Out:
#    match_id  batsman_runs
# 0        12            62
# 1        17            28
# 2        20            64
# 3        27             0
# 4        30            10

# %%
plt.hist(df['batsman_runs'])
plt.show()

# %%
# logarithmic scale
arr = np.load(r'D:\Study\Data Science\Level 1\Frameworks\Matplotlib\Datasets\big-array.npy')
arr
# Out:
# array([33, 39, 37, ..., 33, 30, 39], shape=(11949,))

# %%
# the problem : when some bin has so many values they other bins represntation become almost null to avoid this we use bins
plt.hist(arr , bins = [10,20,30,40,50,60,70] )
plt.show()

# %%
# the solution
plt.hist(arr , bins = [10,20,30,40,50,60,70] , log=True)
plt.show()

# %% [markdown]
# ## pie chart
# Univariate/Bivariate Analysis
# Categorical vs numerical
# Use case - To find contibution on a standard scale

# %%
# simple data
data = [20,30,50,70,90,100]
subjects = ['coa' , 'dm' , 'cn' , 'dsa' , 'history' , 'maths']

plt.pie(data , labels = subjects)
plt.show()

# %%
# dataset
df = pd.read_csv(r'D:\Study\Data Science\Level 1\Frameworks\Matplotlib\Datasets\05_gayle-175.csv')
df
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
plt.pie(df['batsman_runs'] , labels = df['batsman'])
plt.show()

# %%
# percentage
plt.pie(df['batsman_runs'] , labels = df['batsman'] , autopct='%0.1f%%')
plt.show()

# %%
# colors
plt.pie(df['batsman_runs'] , labels = df['batsman'] , colors=['red','green' , 'blue' , 'white' , 'black' , 'orange'])
plt.show()

# %%
# explode
plt.pie(df['batsman_runs'] , labels = df['batsman']  , explode = [0.1 , 0.0 ,0,0,0,0])
plt.show()

# %%
# shadow
plt.pie(df['batsman_runs'] , labels = df['batsman'] , shadow=True , explode = [0.1 , 0.0 ,0,0,0,0])
plt.show()

# %% [markdown]
# ## changing style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
plt.pie(df['batsman_runs'] , labels = df['batsman'] , shadow=True , explode = [0.1 , 0.0 ,0,0,0,0])
plt.show()

# %%
plt.hist(arr , bins = [10,20,30,40,50,60,70] , log=True)
plt.grid()
plt.show()

# %%
## save figure

# %%
plt.hist(arr , bins = [10,20,30,40,50,60,70] , log=True)
plt.grid()
plt.savefig('sample.png')

# %%
## documentation
# examples

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm
from matplotlib.ticker import LinearLocator

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# prepare some coordinates
x, y, z = np.indices((8, 8, 8))

# draw cuboids in the top left and bottom right corners, and a link between
# them
cube1 = (x < 3) & (y < 3) & (z < 3)
cube2 = (x >= 5) & (y >= 5) & (z >= 5)
link = abs(x - y) + abs(y - z) + abs(z - x) <= 2

# combine the objects into a single boolean array
voxelarray = cube1 | cube2 | link

# set the colors of each object
colors = np.empty(voxelarray.shape, dtype=object)
colors[link] = 'red'
colors[cube1] = 'blue'
colors[cube2] = 'green'

# and plot everything
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(voxelarray, facecolors=colors, edgecolor='k')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


def func3(x, y):
    return (1 - x / 2 + x**5 + y**3) * np.exp(-(x**2 + y**2))


# make these smaller to increase the resolution
dx, dy = 0.05, 0.05

x = np.arange(-3.0, 3.0, dx)
y = np.arange(-3.0, 3.0, dy)
X, Y = np.meshgrid(x, y)

# when layering multiple images, the images need to have the same
# extent.  This does not mean they need to have the same shape, but
# they both need to render to the same coordinate system determined by
# xmin, xmax, ymin, ymax.  Note if you use different interpolations
# for the images their apparent extent could be different due to
# interpolation edge effects

extent = np.min(x), np.max(x), np.min(y), np.max(y)
fig = plt.figure(frameon=False)

Z1 = np.add.outer(range(8), range(8)) % 2  # chessboard
im1 = plt.imshow(Z1, cmap=plt.cm.gray, interpolation='nearest',
                 extent=extent)

Z2 = func3(X, Y)

im2 = plt.imshow(Z2, cmap=plt.cm.viridis, alpha=.9, interpolation='bilinear',
                 extent=extent)

plt.show()
