# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## DataFrame Methods

# %%
ipl = pd.read_csv('/content/17_ipl-matches.csv')

# %%
movies = pd.read_csv('/content/17_movies.csv')

# %%
batsman = pd.read_csv('/content/18_batsman_runs_ipl.csv')

# %%
diabetes = pd.read_csv('/content/18_diabetes.csv')

# %% [markdown]
# ### astype()

# %%
#1] astype(series and dataframe)

# %%
ipl = pd.read_csv('/content/17_ipl-matches.csv')

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# always ask each column , can i reduce its memory footprint => if yes reduce it . In big dataset it helps

# %%
ipl['Season']
# Out:
# 0         2022
# 1         2022
# 2         2022
# 3         2022
# 4         2022
#         ...
# 945    2007/08
# 946    2007/08
# 947    2007/08
# 948    2007/08
# 949    2007/08
# Name: Season, Length: 950, dtype: object

# %%
ipl['Season'].dtype
# Out:
# dtype('O')

# %%
ipl['Season'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-463625890.py in <cell line: 0>()
# ----> 1 ipl['Season'].astype('int32')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category') # hota string hi hain , but optimized

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')
ipl['TossWinner'] = ipl['TossWinner'].astype('category')
ipl['WinningTeam'] = ipl['WinningTeam'].astype('category')
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    category
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    category
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# some dataset filtering quetions

# %%
ipl['Player_of_Match'].value_counts().head(10) # player of the match
# Out:
# Player_of_Match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         18
# DA Warner         18
# MS Dhoni          17
# YK Pathan         16
# SR Watson         16
# KA Pollard        14
# SK Raina          14
# V Kohli           14
# Name: count, dtype: int64

# %%
# player of the match in ipl qualifier , eliminator and in final

# %%
 mask = ((ipl['MatchNumber']=='Final') | (ipl['MatchNumber']=='Qualifier 1') | (ipl['MatchNumber']=='Qualifier 2') | (ipl['MatchNumber']=='Eliminator'))

# %%
ipl[mask]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# SK Raina             3
# KA Pollard           2
# AB de Villiers       2
# JJ Bumrah            2
# YK Pathan            2
# M Vijay              2
# F du Plessis         1
# RM Patidar           1
# JC Buttler           1
# HH Pandya            1
# DA Miller            1
# RD Gaikwad           1
# VR Iyer              1
# SR Watson            1
# AD Russell           1
# KH Pandya            1
# SP Narine            1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# DA Warner            1
# BCJ Cutting          1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# MK Pandey            1
# A Nehra              1
# RG Sharma            1
# UT Yadav             1
# V Sehwag             1
# Harbhajan Singh      1
# BJ Hodge             1
# MS Bisla             1
# MEK Hussey           1
# CH Gayle             1
# A Kumble             1
# Name: count, dtype: int64

# %%
# ipl final player of the match

# %%
mask = (ipl['MatchNumber']=='Final')

# %%
ipl[mask]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# HH Pandya       1
# F du Plessis    1
# TA Boult        1
# JJ Bumrah       1
# SR Watson       1
# KH Pandya       1
# BCJ Cutting     1
# RG Sharma       1
# MK Pandey       1
# KA Pollard      1
# MS Bisla        1
# M Vijay         1
# SK Raina        1
# A Kumble        1
# YK Pathan       1
# Name: count, dtype: int64

# %%
# value_counts
# sort_values
# rank
# sort index
# set index
# rename index -> rename
# reset index
# unique & nunique
# isnull/notnull/hasnans
# dropna
# fillna
# drop_duplicates
# drop
# apply
# isin
# corr
# nlargest -> nsmallest
# insert
# copy

# %% [markdown]
# ### value_counts()

# %%
a = pd.Series([1,2,1,2,3,4])
a.value_counts()
# Out:
# 1    2
# 2    2
# 3    1
# 4    1
# Name: count, dtype: int64

# %%
# value_counts(series and dataframe)


marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
],columns=['iq','mark','package'])

marks
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14
# 3   80    70       14
# 4   80    70       14

# %%
marks.value_counts() # not more useful on directly dataframe.
# Out:
# iq   mark  package
# 80   70    14         2
# 90   70    7          1
# 100  80    10         1
# 120  100   14         1
# Name: count, dtype: int64

# %%
# most no of player of the match in qualifiers
ipl = pd.read_csv('/content/17_ipl-matches.csv')
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
# Toss decision plot
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played
(ipl['Team2'].value_counts() + ipl['Team1'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# ### sort_values()

# %%
# sort_values(series and dataframe) -> ascending -> na_position -> inplace -> multiple cols

# %%
x = pd.Series([12,14,1,56,89]) # => how wroks on series
x
# Out:
# 0    12
# 1    14
# 2     1
# 3    56
# 4    89
# dtype: int64

# %%
x.sort_values(ascending=False)
# Out:
# 4    89
# 3    56
# 1    14
# 0    12
# 2     1
# dtype: int64

# %%
movies = pd.read_csv('/content/17_movies.csv')
movies.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
movies.sort_values('title_x') # => working on series
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('title_x',ascending = False) # => ascending and descending
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('title_x',ascending = False,inplace = True) # doing permanant changes

# %%
movies
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name')
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name',ascending = False)
# Out:
#          name college branch   cgpa  package
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name',ascending = False,na_position = 'last') # how to place the na values
# Out:
#          name college branch   cgpa  package
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name',ascending = False,na_position = 'first')
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
movies.sort_values(['year_of_release','title_x']) # according to sequence first it sort based on relearse and then in that year sort based on alphabaticallly.
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### rank

# %%
# rank(series)

# %%
# used to calculate the rank inside the data

# %%
batsman = pd.read_csv('/content/18_batsman_runs_ipl.csv')

# %%
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman['batting rank'] = batsman['batsman_run'].rank(ascending = False) # by deafule ascending ranking

# %%
batsman.sort_values('batting rank')
# Out:
#              batter  batsman_run  batting rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# ### sort_index()

# %%
# sort_index(series and dataframe)

# %%
students = {

       'math' : 100,
       'english' : 89,
       'science' : 78,
       'hindi' : 45,
       'history' : 100
}

# %%
student = pd.Series(students)

# %%
student
# Out:
# math       100
# english     89
# science     78
# hindi       45
# history    100
# dtype: int64

# %%
student.sort_index(ascending = False)
# Out:
# science     78
# math       100
# history    100
# hindi       45
# english     89
# dtype: int64

# %%
movies.sort_index(ascending = False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### set_index()

# %%
# set_index() (dataframe )

# %%
batsman
# Out:
#              batter  batsman_run  batting rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.set_index('batter')
# Out:
#                 batsman_run  batting rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
batsman
# Out:
#              batter  batsman_run  batting rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.set_index('batter',inplace = True)

# %%
batsman
# Out:
#                 batsman_run  batting rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %% [markdown]
# ### reset_index()

# %%
# reset_index(series and dataframe)

# %%
student.reset_index() # reset_index on series convert series into dataframe
# Out:
#      index    0
# 0     math  100
# 1  english   89
# 2  science   78
# 3    hindi   45
# 4  history  100

# %%
batsman.reset_index() # is is also used to set another index without loosing current index
# Out:
#              batter  batsman_run  batting rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.reset_index().set_index("batting rank") # works on dataframe
# Out:
#                       batter  batsman_run
# batting rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# ### rename()

# %%
# rename(dataframe) # changes idex / column name

# %%
movies
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(columns={'title_x':'title' ,'imdb_id':'imdb'},inplace = True); # working with columns

# %%
movies
# Out:
#                          title       imdb  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.set_index('title',inplace=True)

# %%
movies
# Out:
#                                imdb  \
# title
# Zubeidaa                  tt0255713
# Zor Lagaa Ke...Haiya!     tt1479857
# Zokkomon                  tt1605790
# Zindagi Tere Naam         tt2164702
# Zindagi Na Milegi Dobara  tt1562872
# ...                             ...
# 1971 (2007 film)          tt0983990
# 1920: The Evil Returns    tt2222550
# 1920: London              tt5638500
# 1920 (film)               tt1301698
# 16 December (film)        tt0313844
#
#                                                                 poster_path  \
# title
# Zubeidaa                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zor Lagaa Ke...Haiya!     https://upload.wikimedia.org/wikipedia/en/thum...
# Zokkomon                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Tere Naam         https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Na Milegi Dobara  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(index = {'Zubeidaa':'Zubbu','Zor Lagaa Ke...Haiya!':'Zorawar'},inplace = True) # working with indexes

# %%
movies
# Out:
#                                imdb  \
# title
# Zubbu                     tt0255713
# Zorawar                   tt1479857
# Zokkomon                  tt1605790
# Zindagi Tere Naam         tt2164702
# Zindagi Na Milegi Dobara  tt1562872
# ...                             ...
# 1971 (2007 film)          tt0983990
# 1920: The Evil Returns    tt2222550
# 1920: London              tt5638500
# 1920 (film)               tt1301698
# 16 December (film)        tt0313844
#
#                                                                 poster_path  \
# title
# Zubbu                     https://upload.wikimedia.org/wikipedia/en/thum...
# Zorawar                   https://upload.wikimedia.org/wikipedia/en/thum...
# Zokkomon                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Tere Naam         https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Na Milegi Dobara  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### unique()

# %%
# unique(series and dataframe) => gives unique values in series/dataframe

# %%
ipl['Season'].unique() # => working with dataframe
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
temp1 = pd.Series([1,1,2,3,4,4,5,6,6]) # => working with series

# %%
temp1.unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
temp2 = pd.Series([1,1,2,3,4,4,5,6,6,np.nan,np.nan]) # => dealing with nan values

# %%
temp2.unique()# count null values as unique
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6., nan])

# %% [markdown]
# ### nunique()

# %%
# nunique(series and dataframe) => how many unique values in dataframe

# %%
ipl['Season'].nunique()
# Out:
# 15

# %%
temp1.nunique()
# Out:
# 6

# %%
temp2.nunique() # does not count nan as values
# Out:
# 6

# %%
# we can do unique and nunique  work by using value_counts() and count()

# %% [markdown]
# ### isnull()

# %%
# isnull(series and dataframe) => returns true if the value is null(missing)

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students['name'].isnull() # on a series - goes to each value and ask are you null()?
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
students['name'][students['name'].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
students[students['name'].isnull()]
# Out:
#   name college branch  cgpa  package
# 3  NaN     NaN    NaN   NaN      NaN
# 5  NaN    vlsi     ce   9.0      7.0
# 7  NaN     NaN    cse  10.0      9.0
# 9  NaN     git    NaN   NaN      NaN

# %%
students.isnull() # on dataframe jaha pe true hain vaha nan print hua hain and jaha pe false hain vaha pe bhi nan print hua hain , kynki vo false hain
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
students[students.isnull()] # why this weird behaviour
# Out:
#   name college branch  cgpa  package
# 0  NaN     NaN    NaN   NaN      NaN
# 1  NaN     NaN    NaN   NaN      NaN
# 2  NaN     NaN    NaN   NaN      NaN
# 3  NaN     NaN    NaN   NaN      NaN
# 4  NaN     NaN    NaN   NaN      NaN
# 5  NaN     NaN    NaN   NaN      NaN
# 6  NaN     NaN    NaN   NaN      NaN
# 7  NaN     NaN    NaN   NaN      NaN
# 8  NaN     NaN    NaN   NaN      NaN
# 9  NaN     NaN    NaN   NaN      NaN

# %% [markdown]
# ### notnull()

# %%
# notnull(series and dataframe) => opposite of the null()

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
students.notnull() # on dataframe
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %%
students[students.notnull()] # now you can understand why isnull() give all null.
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students['name']
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
students['name'].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# Name: name, dtype: bool

# %%
students['name'][students['name'].notnull()]
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %% [markdown]
# ### hasnans

# %%
# hasnans => tell that the whole series has any null value or not ; if present then return true ele false

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students['name'].hasnans
# Out:
# True

# %% [markdown]
# ### dropna()

# %%
# dropna() => removes all null values

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.dropna() # on dataframe
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
students.dropna(how='any') # any by default value
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
students.dropna(subset = ['name'])
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
students.dropna(subset = ['name','college'])
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
students.dropna(how='all') # if whole row contians null values then he drops it
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students['name']
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
students['name'].dropna() # on series
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
# dropna() is not good att all => leads to loss of data

# %% [markdown]
# ### fillna()

# %%
# fillna(series and dataframe)
# alsways use on series not on dataframe

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.fillna(0) # badpractice always fill individual columns null value
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3           0       0      0   0.00      0.0
# 4  mrityunjay       0     me   5.60      6.0
# 5           0    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7           0       0    cse  10.00      9.0
# 8      aditya       0    bio   7.40      0.0
# 9           0     git      0   0.00      0.0

# %%
students['name'].fillna('unknown',inplace=True)
# Out:
# /tmp/ipython-input-4268331662.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   students['name'].fillna('unknown',inplace=True)

# %%
students['name'].hasnans
# Out:
# False

# %%
students['package'].fillna(students['package'].mean(),inplace = True)
# Out:
# /tmp/ipython-input-470646272.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   students['package'].fillna(students['package'].mean(),inplace = True)

# %%
students['college'].fillna(method = 'ffill')
# Out:
# /tmp/ipython-input-2120807850.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students['college'].fillna(method = 'ffill')
# 0     bit
# 1     iit
# 2     vit
# 3     vit
# 4     vit
# 5    vlsi
# 6    ssit
# 7    ssit
# 8    ssit
# 9     git
# Name: college, dtype: object

# %%
students['college'].ffill()
# Out:
# 0     bit
# 1     iit
# 2     vit
# 3     vit
# 4     vit
# 5    vlsi
# 6    ssit
# 7    ssit
# 8    ssit
# 9     git
# Name: college, dtype: object

# %%
students['college'].bfill()
# Out:
# 0     bit
# 1     iit
# 2     vit
# 3    vlsi
# 4    vlsi
# 5    vlsi
# 6    ssit
# 7     git
# 8     git
# 9     git
# Name: college, dtype: object

# %% [markdown]
# ### drop_duplicates()

# %%
# drop_duplicates() => works on series and dataframe

# %%
marks
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14
# 3   80    70       14
# 4   80    70       14

# %%
marks.drop_duplicates() # on dataframe => if whole row is same the it will be removed
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14
# 3   80    70       14

# %%
marks.drop_duplicates(keep = 'last') # keeps the last occurnace removes first occurence => default ouccrence is first
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14
# 4   80    70       14

# %%
marks['mark'].drop_duplicates() # on series
# Out:
# 0     80
# 1     70
# 2    100
# Name: mark, dtype: int64

# %%
marks
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14
# 3   80    70       14
# 4   80    70       14

# %%
marks.drop_duplicates(subset = ['mark']) # removing duplictes based on the one cloumn , you can give multiple columns
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14

# %%
marks.drop_duplicates(subset = ['mark','iq']) # and ka logic hain
# Out:
#     iq  mark  package
# 0  100    80       10
# 1   90    70        7
# 2  120   100       14
# 3   80    70       14

# %%
# find date of last match played by virat kolhi in delhi

# %%
ipl['City'].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
ipl[( ( ipl['City'] == 'Delhi' ) & ( (ipl['Team1'] == 'Royal Challengers Bangalore') |(ipl['Team2'] == 'Royal Challengers Bangalore') ) )].sort_values('Season',ascending = False).head(1)['Date'].values.item()
# Out:
# '2019-04-28'

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# find date of last match played by virat kolhi in delhi

# %%
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']

# %%
def did_virat_played(players_list):
  return 'V Kohli' in players_list

# %%
did_virat_played()
# Out:
# False

# %%
ipl['did_lohli_played'] = ipl['all_players'].apply(did_virat_played)

# %%
ipl[( ( ipl['City'] == 'Delhi' ) & (ipl['did_lohli_played'] == True) )].drop_duplicates(subset=['City','did_lohli_played'],keep = 'first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_lohli_played
# 208             True
#
# [1 rows x 22 columns]

# %%
# duplicated() => series and dataframe => tells that value or row is duplicated or not

# %%
marks.duplicated().sum().item()
# Out:
# 1

# %% [markdown]
# ### drop()

# %%
# drop() => series and dataframe  used to remove column and row

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students['name']
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
students['name'].drop(index = [0,8]) # on series
# Out:
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 9           NaN
# Name: name, dtype: object

# %%
students.drop(columns = ['branch','cgpa']) # on columns
# Out:
#          name college  package
# 0      nitish     bit      4.0
# 1       ankit     iit      5.0
# 2      rupesh     vit      6.0
# 3         NaN     NaN      NaN
# 4  mrityunjay     NaN      6.0
# 5         NaN    vlsi      7.0
# 6     rishabh    ssit      8.0
# 7         NaN     NaN      9.0
# 8      aditya     NaN      NaN
# 9         NaN     git      NaN

# %%
# works on labelled index

# %%
students.set_index('name').drop(index = ['ankit','mrityunjay'])
# Out:
#         college branch   cgpa  package
# name
# nitish      bit    eee   6.66      4.0
# rupesh      vit    cse   6.41      6.0
# NaN         NaN    NaN    NaN      NaN
# NaN        vlsi     ce   9.00      7.0
# rishabh    ssit    civ   7.40      8.0
# NaN         NaN    cse  10.00      9.0
# aditya      NaN    bio   7.40      NaN
# NaN         git    NaN    NaN      NaN

# %% [markdown]
# ### apply()

# %%
# apply() Series and dataframe

# %%
temp = pd.Series([10,20,30,40,50])

temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
def sigmoid(value):
  return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid) # how it works:take each value from temp and send to sigmoid function and that function returns the ans
                      # it goes column wise
# Out:
# 0    1.000045
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
# see dataframe => series column wise , df row wise => 1 value in series = 1 row

# %%
def euclidean(row):
  pt_A = row['1st point']
  pt_B = row['2nd point']

  return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000

# %% [markdown]
# ### next()
