# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
pwd
# Out:
# '/content'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %% [markdown]
# ## Categorical Plots
# ### Categorical Scatter Plot => bivariate analysis
# Stripplot
# Swarmplot
#
# ### Categorical Distribution Plots => univariate analysis
# Boxplot
# Violinplot
#
# ### Categorical Estimate Plot -> for central tendency
# Barplot
# Pointplot
# Countplot
#
# Figure level function -> catplot

# %%
sns.scatterplot(data=tips , x ='total_bill' , y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## stripplot()

# %%
# axes level function
sns.stripplot(data = tips , x = 'day' , y = 'total_bill' )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# using catplot
# figure level function
sns.catplot(data = tips , x ='day' , y = 'total_bill' , kind = 'strip')

# %%
# jitter => distubance added by seaborn itself to read visisbality
# above code are with jitter

# %%
sns.catplot(data = tips , x ='day' , y = 'total_bill' , kind = 'strip' , jitter = False)

# %%
sns.catplot(data = tips , x ='day' , y = 'total_bill' , kind = 'strip' , jitter = 0.3)

# %%
#hue
sns.stripplot(data  = tips , x = 'day' , y = 'total_bill', hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### swarmplot()
# shows Right distribution by running an internal algorithm

# %%
sns.catplot(data = tips , x = 'day' , y ='total_bill' , kind = 'swarm')

# %%
sns.swarmplot(data  = tips , x = 'day' , y = 'total_bill') # axes level function
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# hue
sns.swarmplot(data  = tips , x = 'day' , y = 'total_bill' , hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Boxplot
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.
#
# ![image.png](data:image/png;base64,...)

# %%
# box plot
sns.boxplot(data = tips , x = 'sex' , y = 'total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data = tips , x = 'total_bill' , y = 'sex') # got cooked
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
# using catplot
sns.catplot(data = tips , x = 'sex' , y= 'total_bill' , kind = 'box')

# %%
# hue
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , hue = 'smoker' , kind = 'box')

# %%
# faceting
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , hue = 'smoker' , kind = 'box' , col = 'sex' , row = 'day')

# %%
# single boxplot => numeric columns
sns.boxplot(data = tips , y = 'total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
# single boxplot => categorical columns => useless on single categorical columns
sns.boxplot(data = tips , y = 'day')
# Out:
# <Axes: ylabel='day'>

# %% [markdown]
# ## violin plot = (kdeplot + boxplot)

# %%
sns.violinplot(data = tips , x = 'sex' , y = 'tip') # always take categorical column on x axis => better understanding
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.catplot(data = tips , x = 'total_bill' , y = 'smoker' , kind = 'violin') # this happenes when you put the categorical column on y axis

# %%
# hue
sns.violinplot(data = tips , x = 'sex' , y = 'tip' , hue = 'smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# split
sns.catplot(data = tips , x='day' , y = 'tip' , hue = 'sex' , kind = 'violin' , split = 'hue')

# %% [markdown]
# ## barplot()

# %%
import numpy as np

# %%
sns.barplot(data = tips , x = 'sex' , y = 'total_bill' ) # axes level
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , kind = 'bar') # fig level

# %%
# estimator
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , kind = 'bar' , estimator = 'median')

# %%
# hue
sns.barplot(data = tips , x ='sex' , y = 'total_bill' , hue = 'smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# hue
sns.barplot(data = tips , x ='sex' , y = 'total_bill' , hue = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# errorbar
sns.barplot(data = tips , x ='sex' , y = 'total_bill' , hue = 'smoker' , errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.catplot(data = tips , x ='day' , y = 'tip',hue = 'smoker',errorbar = None , kind = 'bar')

# %% [markdown]
# ## pointplot()
#  When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars

# %%
# joing tips of barplot
# pointplot = barplot - bar

# %%
sns.barplot(data = tips , x ='day' , y = 'tip') # for understanding
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.pointplot(data = tips , x ='day' , y = 'tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.pointplot(data = tips , x ='day' , y = 'tip',errorbar = None)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# hue
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , kind = 'point' , hue = 'smoker',errorbar=None)

# %%
#hue
sns.pointplot(data = tips , x ='day' , y = 'tip',hue = 'sex',errorbar = None)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data = tips , x ='day' , y = 'tip',hue = 'sex',errorbar = None)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## countplot()
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing a statistic for a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable

# %%
sns.countplot(data = tips , x ='sex' )
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data = tips , y ='sex' )
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.catplot(data = tips , x ='day', kind = 'count')

# %%
# hue
sns.catplot(data = tips , x ='sex', kind = 'count' , hue = 'day')

# %%
# faceting using catplot

# %%
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , kind = 'box' , hue = 'smoker' , col = 'sex' , row = 'day')

# %% [markdown]
# # Regression Plots
# regplot
# lmplot
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.

# %%
# axes level
# hue parameter is not available
#numerical column only
sns.regplot(data = tips , x = 'total_bill' , y = 'tip' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# fig level
# hue is avilabel
sns.lmplot(data = tips , x = 'total_bill' , y ='tip' , hue = 'sex')

# %%
# residplot
sns.residplot(data = tips , x = 'total_bill' , y = 'tip' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Multiplot()

# %% [markdown]
# ## Facetgrid

# %%
# A second way to plot Facet plots

# %%
sns.catplot(data = tips , x = 'sex' , y = 'total_bill' , kind = 'box' , hue = 'smoker' , col = 'sex' , row = 'day')

# %%
# another way
g = sns.FacetGrid(data = tips , col = 'sex' , row = 'day' )
g.map(sns.boxplot ,'sex' ,  'tip')
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# facetplot is based on Facetgrid

# %% [markdown]
# ## pairplot()

# %%
# realation of each numerical column with another numerical columns

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris , hue = 'species')

# %% [markdown]
# ## PairGrid

# %%
g = sns.PairGrid(data = iris)
g.map(sns.scatterplot)

# %%
# hue
g = sns.PairGrid(data = iris , hue ='species')
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(data = iris)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data = iris , hue = 'species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data = iris , hue = 'species')
g.map_diag(sns.boxenplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data = iris , hue = 'species')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.histplot)

# %%
g = sns.PairGrid(data = iris , hue = 'species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %% [markdown]
# ## jointplot and JointGrid

# %%
sns.jointplot(data = tips , x ='total_bill' , y ='tip')

# %%
# kind 
sns.jointplot(data = tips , x ='total_bill' , y ='tip' , kind = 'hex')

# %%
# hue
sns.jointplot(data = tips , x ='total_bill' , y ='tip' , hue = 'sex')

# %% [markdown]
# ### JointGrid
# allow cutomization in jointplot

# %%
g = sns.JointGrid(data = tips , x = 'total_bill' , y='tip' )
g.plot(sns.scatterplot , sns.histplot)

# %%
g = sns.JointGrid(data = tips , x = 'total_bill' , y='tip' , hue = 'sex')
g.plot(sns.histplot , sns.stripplot)

# %%
g = sns.JointGrid(data = tips , x = 'total_bill' , y='tip' , hue = 'sex')
g.plot(sns.histplot , sns.stripplot)

# %% [markdown]
# ## utility functions

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('healthexp')
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]
