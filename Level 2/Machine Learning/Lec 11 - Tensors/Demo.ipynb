# %%
import numpy as np

# %%
n = np.array(4)

# %%
n
# Out:
# array(4)

# %%
n.ndim
# Out:
# 0

# %% [markdown]
# # 1D Tensor

# %%
arr = np.array([1,2,3,4])

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.ndim
# Out:
# 1

# %% [markdown]
# # 2D Tensor

# %%
arr2 = np.array([[1,2,3] , [4,5,6]])

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr2.ndim
# Out:
# 2
